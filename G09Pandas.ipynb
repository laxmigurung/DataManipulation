# %%
# Group Number: 09
# Group Member: Laxmi Gurung and Neja Gurung
# Project: Using the appstoregames.cs file, write python code to read the file 
#        into a Pandas DataFrame analyze the data.
# Date: 11/01/2021


# Import the libraries numpy and pandas for data manipulation.
import pandas as pd
import numpy as np

# Reading the csv file.
appStoreGames = pd.read_csv('appstoregames.csv')

# %%
# 1. Use the appropriate Pandas method to describe the characteristics of your dataset.
appStoreGames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            17007 non-null  int64
#  1   Name                          17007 non-null  object
#  2   Subtitle                      5261 non-null   object
#  3   User Rating                   7561 non-null   float64
#  4   Count of Ratings              7561 non-null   float64
#  5   Price                         16983 non-null  float64
#  6   In-app Purchases              7683 non-null   object
#  7   Developer                     17007 non-null  object
#  8   Age Rating                    17007 non-null  object
#  9   Languages                     16947 non-null  object
#  10  Size                          17006 non-null  float64
#  11  Genre                         17007 non-null  object
# ...

# %%
# 2. Count and show the number of apps in each genre
appStoreGames['Genre'].value_counts() #a quick way to count the unique values in a single column
# Out:
# Games                16286
# Education              222
# Entertainment          198
# Utilities               77
# Sports                  60
# Reference               32
# Stickers                29
# Finance                 18
# Business                16
# Productivity            15
# Lifestyle               10
# Book                     9
# Social Networking        9
# News                     7
# Health & Fitness         5
# Food & Drink             4
# Music                    3
# Navigation               3
# Medical                  2
# Travel                   1
# Shopping                 1
# Name: Genre, dtype: int64

# %%
# 3. Show all statistics of user ratings and size on the same summary table

appStoreGames[['User Rating','Size']].describe()
# Out:
#        User Rating          Size
# count  7561.000000  1.700600e+04
# mean      4.060905  1.157064e+08
# std       0.751428  2.036477e+08
# min       1.000000  5.132800e+04
# 25%       3.500000  2.295014e+07
# 50%       4.500000  5.676895e+07
# 75%       4.500000  1.330271e+08
# max       5.000000  4.005591e+09

# %%
# 4. Filter the dataset to count and show all paid apps with ratings under 1.5

# All the paid apps that are greater than stored in paidAppsAboveZero
paidAppsAboveZero = appStoreGames['Price']>0
#appStoreGames[paidAppsAboveZero]

# All the apps which has User Rating below than 1.5
lowerRatings = appStoreGames['User Rating']<1.5

print("The total number of apps that are paid and User Rating is below 1.5 :",
      appStoreGames[lowerRatings & paidAppsAboveZero]['Name'].count())
# Out:
# The total number of apps that are paid and user rating is below 1.5 : 9

# %%
#Displaying the apps that costs above Zero and has User Rating below 1.5
appStoreGames[lowerRatings & paidAppsAboveZero]
# Out:
#                ID                                               Name Subtitle  \
# 1957    601301449          NORTH & SOUTH - The Game (Pocket Edition)      NaN
# 2141    633006816  Haunted Island : Mystic of Anarchy Wild Escape 3D      NaN
# 3984    884768672  Design CAD - create and edit DWG/DXF/CTM drawi...      NaN
# 5572    969107262                                   Venture for iPad      NaN
# 6103    993863316  Escape Mystery Haunted House -Scary Point & Cl...      NaN
# 6422   1015151892                      Nuts! The Battle of the Bulge      NaN
# 7385   1062521052                                  Backgammon Skills      NaN
# 11011  1205436748                  Harbor Master: Caribbean Merchant      NaN
# 12235  1258100671                                   Lightning: D-Day      NaN
#
#        User Rating  Count of Ratings  Price In-app Purchases  \
# 1957           1.0               7.0   1.99              NaN
# 2141           1.0              14.0   2.99              NaN
# ...

# %%
#5. Write Python code to calculate which percentage of the apps in the dataset are free. 
#Do not change Nan values to zero. Print the percentage on a 100 basis with no more than 2 decimals.


# Using '==' operator to extract all the free apps
appsBelowZero = appStoreGames['Price'] == 0
freeApps = appStoreGames[appsBelowZero]['Price'].count() # counting number of free apps
#print(freeApps)

# To count the total number of apps including the Nan values because non-null value in Price = 16983.
totalApps = appStoreGames['Name'].count()
#print(totalApps)

freeAppsRate = (freeApps/totalApps)*100

print(f"The percentage of the free apps is {freeAppsRate:.2f}% .")
# Out:
# The percentage of the free apps is 83.57% .
